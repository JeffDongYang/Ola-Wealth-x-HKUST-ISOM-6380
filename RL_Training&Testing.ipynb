# %%
import gym
from gym import spaces
import numpy as np
import pandas as pd
import pickle
import json
from stable_baselines3 import SAC

# ========= 1. 数据预处理 =========
with open("trade_signals.json", "r", encoding="utf-8") as f:
    signals_data = json.load(f)

filtered_signals = [
    d for d in signals_data
    if 'Signal' in d and 'Pattern' in d and 'Take Profit' in d and 'Stop Loss' in d
]

# 统计所有出现过的类别
all_signals = sorted(list(set(d['Signal'] for d in filtered_signals)))
all_patterns = sorted(list(set(d['Pattern'] for d in filtered_signals)))
all_codes = sorted(list(set(d['Code'] for d in filtered_signals)))

# 增加"other"类别，必须放在最后一位
all_signals.append('other')
all_patterns.append('other')
all_codes.append('other')

# 保存类别，推理时要用
with open("env_categories.pkl", "wb") as f:
    pickle.dump({
        "signal_types": all_signals,
        "patterns": all_patterns,
        "codes": all_codes
    }, f)

# ========= 2. 环境定义 =========
def get_index_with_other(cat_list, item):
    try:
        return cat_list.index(item)
    except ValueError:
        return len(cat_list) - 1  # "other"

class TradingEnv(gym.Env):
    def __init__(self, data, signal_types, patterns, codes,
                 tp_range=(0.9, 1.25), sl_range=(0.95, 1.01)):
        super().__init__()
        self.data = data
        self.signal_types = signal_types
        self.patterns = patterns
        self.codes = codes
        self.n_signals = len(signal_types)
        self.n_patterns = len(patterns)
        self.n_codes = len(codes)
        self.numeric_features = 8
        self.current_step = 0

        obs_len = self.n_signals + self.n_patterns + self.n_codes + self.numeric_features
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf,
            shape=(obs_len,),
            dtype=np.float32
        )
        self.action_space = spaces.Box(
            low=np.array([tp_range[0], sl_range[0]], dtype=np.float32),
            high=np.array([tp_range[1], sl_range[1]], dtype=np.float32),
            dtype=np.float32
        )

    def reset(self):
        self.current_step = 0
        return self._get_obs()

    def _get_obs(self):
        if self.current_step >= len(self.data):
            return np.zeros(self.observation_space.shape, dtype=np.float32)
        d = self.data[self.current_step]
        # one-hot，未知类别归到"other"位
        signal_onehot = np.zeros(self.n_signals, dtype=np.float32)
        pattern_onehot = np.zeros(self.n_patterns, dtype=np.float32)
        code_onehot = np.zeros(self.n_codes, dtype=np.float32)
        si = get_index_with_other(self.signal_types, d['Signal'])
        pi = get_index_with_other(self.patterns, d['Pattern'])
        ci = get_index_with_other(self.codes, d['Code'])
        signal_onehot[si] = 1
        pattern_onehot[pi] = 1
        code_onehot[ci] = 1

        entry_price = float(d.get('Entry Price', 1))
        volume = float(d.get('Volume', 0)) / entry_price
        volatility = float(d.get('Volatility', 0)) / entry_price
        tp = float(d.get('Take Profit', 0)) / entry_price
        sl = float(d.get('Stop Loss', 0)) / entry_price
        atr = float(d.get('ATR', 0)) / entry_price

        try:
            dt = pd.to_datetime(d['Timestamp'])
            hour_of_day = dt.hour / 23.0
            day_of_week = dt.weekday() / 6.0
        except Exception:
            hour_of_day = 0.0
            day_of_week = 0.0

        obs = np.concatenate([
            signal_onehot, pattern_onehot, code_onehot,
            [volume, volatility, tp, sl, hour_of_day, day_of_week, 1.0, atr]
        ])
        if obs.shape[0] != self.observation_space.shape[0]:
            raise ValueError(f"obs shape {obs.shape} != {self.observation_space.shape}")
        return obs

    def step(self, action):
        tp, sl = action
        d = self.data[self.current_step]
        entry_price = float(d.get('Entry Price', 1))
        best_tp = float(d['Take Profit']) / entry_price
        best_sl = float(d['Stop Loss']) / entry_price
        diff = abs(tp - best_tp) + abs(sl - best_sl)
        reward = 1.0 if diff < 0.01 else -1.0
        self.current_step += 1
        done = self.current_step >= len(self.data)
        obs_dim = self.observation_space.shape[0]
        obs = self._get_obs() if not done else np.zeros(obs_dim, dtype=np.float32)
        info = {}
        return obs, reward, done, info

    def render(self, mode='human'):
        pass

    def close(self):
        pass

# ========= 3. 训练 =========
env = TradingEnv(
    filtered_signals,
    signal_types=all_signals,
    patterns=all_patterns,
    codes=all_codes
)
model = SAC('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=200_000)
model.save("sac_trading_agent")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12e+03 |
# |    ep_rew_mean     | -1.6e+03 |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 18       |
# |    time_elapsed    | 1341     |
# |    total_timesteps | 24480    |
# | train/             |          |
# |    actor_loss      | 38.3     |
# |    critic_loss     | 0.547    |
# |    ent_coef        | 0.317    |
# |    ent_coef_loss   | -0.013   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24379    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12e+03 |
# |    ep_rew_mean     | -107     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 17       |
# |    time_elapsed    | 2744     |
# |    total_timesteps | 48960    |
# | train/             |          |
# |    actor_loss      | 50.8     |
# |    critic_loss     | 0.388    |
# |    ent_coef        | 0.334    |
# |    ent_coef_loss   | -0.176   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48859    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12e+03 |
# |    ep_rew_mean     | 538      |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 17       |
# |    time_elapsed    | 4227     |
# |    total_timesteps | 73440    |
# | train/             |          |
# |    actor_loss      | 50.7     |
# |    critic_loss     | 0.342    |
# |    ent_coef        | 0.366    |
# |    ent_coef_loss   | -0.00549 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 73339    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12e+03 |
# |    ep_rew_mean     | 888      |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 16       |
# |    time_elapsed    | 5811     |
# |    total_timesteps | 97920    |
# | train/             |          |
# |    actor_loss      | 49.8     |
# |    critic_loss     | 0.336    |
# |    ent_coef        | 0.37     |
# |    ent_coef_loss   | -0.0913  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 97819    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12e+03 |
# |    ep_rew_mean     | 1.1e+03  |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 16       |
# |    time_elapsed    | 7412     |
# |    total_timesteps | 122400   |
# | train/             |          |
# |    actor_loss      | 50.4     |
# |    critic_loss     | 0.194    |
# |    ent_coef        | 0.366    |
# |    ent_coef_loss   | -0.00337 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 122299   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12e+03 |
# |    ep_rew_mean     | 1.26e+03 |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 16       |
# |    time_elapsed    | 9046     |
# |    total_timesteps | 146880   |
# | train/             |          |
# |    actor_loss      | 50.6     |
# |    critic_loss     | 0.334    |
# |    ent_coef        | 0.369    |
# |    ent_coef_loss   | 0.0474   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 146779   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12e+03 |
# |    ep_rew_mean     | 1.38e+03 |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 16       |
# |    time_elapsed    | 10692    |
# |    total_timesteps | 171360   |
# | train/             |          |
# |    actor_loss      | 50.1     |
# |    critic_loss     | 0.148    |
# |    ent_coef        | 0.382    |
# |    ent_coef_loss   | 0.124    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 171259   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12e+03 |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 15       |
# |    time_elapsed    | 12368    |
# |    total_timesteps | 195840   |
# | train/             |          |
# |    actor_loss      | 49.1     |
# |    critic_loss     | 0.158    |
# |    ent_coef        | 0.37     |
# |    ent_coef_loss   | 0.21     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 195739   |
# ---------------------------------

# %%
import gym
from gym import spaces
import numpy as np
import pandas as pd
import pickle
import json
from stable_baselines3 import SAC
import pickle

# ========= 1. 数据预处理 =========
with open("test_trade_signals.json", "r", encoding="utf-8") as f:
    signals_data = json.load(f)

filtered_signals = [
    d for d in signals_data
    if 'Signal' in d and 'Pattern' in d and 'Take Profit' in d and 'Stop Loss' in d
]

# 统计所有出现过的类别
all_signals = sorted(list(set(d['Signal'] for d in filtered_signals)))
all_patterns = sorted(list(set(d['Pattern'] for d in filtered_signals)))
all_codes = sorted(list(set(d['Code'] for d in filtered_signals)))

# 增加"other"类别，必须放在最后一位
all_signals.append('other')
all_patterns.append('other')
all_codes.append('other')

# 保存类别，推理时要用
with open("env_categories.pkl", "wb") as f:
    pickle.dump({
        "signal_types": all_signals,
        "patterns": all_patterns,
        "codes": all_codes
    }, f)

# ========= 2. 环境定义 =========
def get_index_with_other(cat_list, item):
    try:
        return cat_list.index(item)
    except ValueError:
        return len(cat_list) - 1  # "other"

class TradingEnv(gym.Env):
    def __init__(self, data, signal_types, patterns, codes,
                 tp_range=(0.9, 1.25), sl_range=(0.95, 1.01)):
        super().__init__()
        self.data = data
        self.signal_types = signal_types
        self.patterns = patterns
        self.codes = codes
        self.n_signals = len(signal_types)
        self.n_patterns = len(patterns)
        self.n_codes = len(codes)
        self.numeric_features = 8
        self.current_step = 0

        obs_len = self.n_signals + self.n_patterns + self.n_codes + self.numeric_features
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf,
            shape=(obs_len,),
            dtype=np.float32
        )
        self.action_space = spaces.Box(
            low=np.array([tp_range[0], sl_range[0]], dtype=np.float32),
            high=np.array([tp_range[1], sl_range[1]], dtype=np.float32),
            dtype=np.float32
        )

    def reset(self):
        self.current_step = 0
        return self._get_obs()

    def _get_obs(self):
        if self.current_step >= len(self.data):
            return np.zeros(self.observation_space.shape, dtype=np.float32)
        d = self.data[self.current_step]
        # one-hot，未知类别归到"other"位
        signal_onehot = np.zeros(self.n_signals, dtype=np.float32)
        pattern_onehot = np.zeros(self.n_patterns, dtype=np.float32)
        code_onehot = np.zeros(self.n_codes, dtype=np.float32)
        si = get_index_with_other(self.signal_types, d['Signal'])
        pi = get_index_with_other(self.patterns, d['Pattern'])
        ci = get_index_with_other(self.codes, d['Code'])
        signal_onehot[si] = 1
        pattern_onehot[pi] = 1
        code_onehot[ci] = 1

        entry_price = float(d.get('Entry Price', 1))
        volume = float(d.get('Volume', 0)) / entry_price
        volatility = float(d.get('Volatility', 0)) / entry_price
        tp = float(d.get('Take Profit', 0)) / entry_price
        sl = float(d.get('Stop Loss', 0)) / entry_price
        atr = float(d.get('ATR', 0)) / entry_price

        try:
            dt = pd.to_datetime(d['Timestamp'])
            hour_of_day = dt.hour / 23.0
            day_of_week = dt.weekday() / 6.0
        except Exception:
            hour_of_day = 0.0
            day_of_week = 0.0

        obs = np.concatenate([
            signal_onehot, pattern_onehot, code_onehot,
            [volume, volatility, tp, sl, hour_of_day, day_of_week, 1.0, atr]
        ])
        if obs.shape[0] != self.observation_space.shape[0]:
            raise ValueError(f"obs shape {obs.shape} != {self.observation_space.shape}")
        return obs

    def step(self, action):
        tp, sl = action
        d = self.data[self.current_step]
        entry_price = float(d.get('Entry Price', 1))
        best_tp = float(d['Take Profit']) / entry_price
        best_sl = float(d['Stop Loss']) / entry_price
        diff = abs(tp - best_tp) + abs(sl - best_sl)
        reward = 1.0 if diff < 0.01 else -1.0
        self.current_step += 1
        done = self.current_step >= len(self.data)
        obs_dim = self.observation_space.shape[0]
        obs = self._get_obs() if not done else np.zeros(obs_dim, dtype=np.float32)
        info = {}
        return obs, reward, done, info

    def render(self, mode='human'):
        pass

    def close(self):
        pass

with open("env_categories.pkl", "rb") as f:
    cats = pickle.load(f)

new_env = TradingEnv(
    filtered_signals,
    signal_types=cats['signal_types'],
    patterns=cats['patterns'],
    codes=cats['codes']
)
model = SAC.load("sac_trading_agent", env=new_env)
obs = new_env.reset()
done = False
while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, info = new_env.step(action)
    print(f"Predicted Take Profit: {action[0]:.4f}, Predicted Stop Loss: {action[1]:.4f}")
    print("Number of trading signals in the dataset:", len(filtered_signals))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 142
#     134     cats = pickle.load(f)
#     136 new_env = TradingEnv(
#     137     filtered_signals,
#     138     signal_types=cats['signal_types'],
#     139     patterns=cats['patterns'],
#     140     codes=cats['codes']
#     141 )
# --> 142 model = SAC.load("sac_trading_agent", env=new_env)
#     143 obs = new_env.reset()
#     144 done = False
#
# File D:\anaconda\Anaconda\Lib\site-packages\stable_baselines3\common\base_class.py:717, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     715 env = cls._wrap_env(env, data["verbose"])
#     716 # Check if given env is valid
# --> 717 check_for_correct_spaces(env, data["observation_space"], data["action_space"])
#     718 # Discard `_last_obs`, this will force the env to reset before training
#     719 # See issue https://github.com/DLR-RM/stable-baselines3/issues/597
#     720 if force_reset and data is not None:
#
# File D:\anaconda\Anaconda\Lib\site-packages\stable_baselines3\common\utils.py:232, in check_for_correct_spaces(env, observation_space, action_space)
#     220 """
#     221 Checks that the environment has same spaces as provided ones. Used by BaseAlgorithm to check if
#     222 spaces match after loading the model with given env.
#    (...)
#     229 :param action_space: Action space to check against
#     230 """
#     231 if observation_space != env.observation_space:
# --> 232     raise ValueError(f"Observation spaces do not match: {observation_space} != {env.observation_space}")
#     233 if action_space != env.action_space:
#     234     raise ValueError(f"Action spaces do not match: {action_space} != {env.action_space}")
#
# ValueError: Observation spaces do not match: Box(-inf, inf, (29,), float32) != Box(-inf, inf, (17,), float32)

# %%
import gym
from gym import spaces
import numpy as np
import pandas as pd
import pickle
import json
from stable_baselines3 import SAC

class TradingEnv(gym.Env):
    def __init__(self, data, categories_dict=None, tp_range=(1.0, 1.25), sl_range=(0.95, 0.99)):
        super().__init__()
        self.data = data
        
        if categories_dict is None:
            # 训练时收集所有类别
            self.signal_types = sorted(list(set(d['Signal'] for d in data)))
            self.patterns = sorted(list(set(d['Pattern'] for d in data)))
            self.codes = sorted(list(set(d['Code'] for d in data)))
            
            # 增加"other"类别
            self.signal_types.append('other')
            self.patterns.append('other')
            self.codes.append('other')
            
            # 保存类别字典
            self.categories_dict = {
                'signal_types': self.signal_types,
                'patterns': self.patterns,
                'codes': self.codes
            }
        else:
            # 使用提供的类别字典
            self.categories_dict = categories_dict
            self.signal_types = categories_dict['signal_types']
            self.patterns = categories_dict['patterns']
            self.codes = categories_dict['codes']
        
        self.n_signals = len(self.signal_types)
        self.n_patterns = len(self.patterns)
        self.n_codes = len(self.codes)
        self.numeric_features = 8
        self.current_step = 0
        
        obs_len = self.n_signals + self.n_patterns + self.n_codes + self.numeric_features
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf,
            shape=(obs_len,),
            dtype=np.float32
        )
        self.action_space = spaces.Box(
            low=np.array([tp_range[0], sl_range[0]], dtype=np.float32),
            high=np.array([tp_range[1], sl_range[1]], dtype=np.float32),
            dtype=np.float32
        )
    
    def reset(self):
        self.current_step = 0
        return self._get_obs()
    
    def _get_obs(self):
        if self.current_step >= len(self.data):
            return np.zeros(self.observation_space.shape, dtype=np.float32)
        
        d = self.data[self.current_step]
        # one-hot编码
        signal_onehot = np.zeros(self.n_signals, dtype=np.float32)
        pattern_onehot = np.zeros(self.n_patterns, dtype=np.float32)
        code_onehot = np.zeros(self.n_codes, dtype=np.float32)
        
        # 使用索引，如果类别不存在则使用"other"
        si = self.signal_types.index(d['Signal']) if d['Signal'] in self.signal_types else self.n_signals - 1
        pi = self.patterns.index(d['Pattern']) if d['Pattern'] in self.patterns else self.n_patterns - 1
        ci = self.codes.index(d['Code']) if d['Code'] in self.codes else self.n_codes - 1
        
        signal_onehot[si] = 1
        pattern_onehot[pi] = 1
        code_onehot[ci] = 1
        
        # 其他特征
        entry_price = float(d.get('Entry Price', 1))
        volume = float(d.get('Volume', 0)) / entry_price
        volatility = float(d.get('Volatility', 0)) / entry_price
        tp = float(d.get('Take Profit', 0)) / entry_price
        sl = float(d.get('Stop Loss', 0)) / entry_price
        atr = float(d.get('ATR', 0)) / entry_price
        
        # 时间特征
        try:
            dt = pd.to_datetime(d['Timestamp'])
            hour_of_day = dt.hour / 23.0
            day_of_week = dt.weekday() / 6.0
        except Exception:
            hour_of_day = 0.0
            day_of_week = 0.0
        
        obs = np.concatenate([
            signal_onehot, pattern_onehot, code_onehot,
            [volume, volatility, tp, sl, hour_of_day, day_of_week, 1.0, atr]
        ])
        return obs
    
    def step(self, action):
        tp, sl = action
        d = self.data[self.current_step]
        entry_price = float(d.get('Entry Price', 1))
        best_tp = float(d['Take Profit']) / entry_price
        best_sl = float(d['Stop Loss']) / entry_price
        diff = abs(tp - best_tp) + abs(sl - best_sl)
        reward = 1.0 if diff < 0.01 else -1.0
        self.current_step += 1
        done = self.current_step >= len(self.data)
        obs = self._get_obs() if not done else np.zeros(self.observation_space.shape, dtype=np.float32)
        info = {}
        
        return obs, reward, done, info
    
    def render(self, mode='human'):
        pass
    
    def close(self):
        pass

# 训练代码
'''
with open("trade_signals.json", "r", encoding="utf-8") as f:
    signals_data = json.load(f)

env = TradingEnv(signals_data)
model = SAC('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=200_000)
model.save("sac_trading_agent")

# 保存类别字典
with open("categories_dict.json", "w") as f:
    json.dump(env.categories_dict, f)
'''

# 加载和预测代码
# 首先加载类别字典
with open("categories_dict.json", "r") as f:
    categories_dict = json.load(f)

# 加载测试数据
with open("test_trade_signals.json", "r", encoding="utf-8") as f:
    test_signals_data = json.load(f)

# 使用相同的类别字典创建测试环境
new_env = TradingEnv(test_signals_data, categories_dict=categories_dict)

# 加载模型
model = SAC.load("sac_trading_agent", env=new_env)

# 进行预测
obs = new_env.reset()
done = False
total_reward = 0
predictions = []

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, info = new_env.step(action)
    total_reward += reward
    
    # 获取当前数据用于记录
    if new_env.current_step - 1 < len(test_signals_data):
        current_data = test_signals_data[new_env.current_step - 1]
        predictions.append({
            'Signal': current_data['Signal'],
            'Pattern': current_data['Pattern'],
            'Code': current_data['Code'],
            'Predicted_TP': float(action[0]),
            'Predicted_SL': float(action[1]),
            'Actual_TP': float(current_data['Take Profit']) / float(current_data.get('Entry Price', 1)),
            'Actual_SL': float(current_data['Stop Loss']) / float(current_data.get('Entry Price', 1)),
            'Reward': reward
        })
        print(f"Signal: {current_data['Signal']}, TP: {action[0]:.4f}, SL: {action[1]:.4f}, Reward: {reward}")

print(f"\n总奖励: {total_reward}")
print(f"平均奖励: {total_reward / len(test_signals_data):.4f}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Signal: Buy Long, TP: 1.0309, SL: 0.9831, Reward: -1.0
# Signal: Buy Long, TP: 1.1613, SL: 0.9756, Reward: -1.0
# Signal: Buy Long, TP: 1.0268, SL: 0.9833, Reward: -1.0
# Signal: Buy Long, TP: 1.0113, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0113, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0114, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0110, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1476, SL: 0.9717, Reward: -1.0
# Signal: Buy Long, TP: 1.0107, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0106, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0105, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0101, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1205, SL: 0.9721, Reward: -1.0
# Signal: Buy Long, TP: 1.1164, SL: 0.9725, Reward: -1.0
# Signal: Buy Long, TP: 1.0144, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0144, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0141, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0135, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0134, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0129, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0127, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0123, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0115, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0533, SL: 0.9828, Reward: -1.0
# Signal: Buy Long, TP: 1.0108, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0110, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0103, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0099, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.1281, SL: 0.9704, Reward: -1.0
# Signal: Buy Long, TP: 1.0090, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.1156, SL: 0.9730, Reward: -1.0
# Signal: Buy Long, TP: 1.0393, SL: 0.9800, Reward: -1.0
# Signal: Buy Long, TP: 1.0090, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.1310, SL: 0.9696, Reward: -1.0
# Signal: Buy Long, TP: 1.0080, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0071, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.1548, SL: 0.9690, Reward: -1.0
# Signal: Buy Long, TP: 1.1569, SL: 0.9685, Reward: -1.0
# Signal: Buy Long, TP: 1.1394, SL: 0.9742, Reward: -1.0
# Signal: Buy Long, TP: 1.1465, SL: 0.9697, Reward: -1.0
# Signal: Buy Long, TP: 1.1650, SL: 0.9697, Reward: -1.0
# Signal: Buy Long, TP: 1.0460, SL: 0.9860, Reward: -1.0
# Signal: Buy Long, TP: 1.1119, SL: 0.9720, Reward: -1.0
# Signal: Buy Long, TP: 1.0088, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0079, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0085, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.1248, SL: 0.9713, Reward: -1.0
# Signal: Buy Long, TP: 1.0096, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1187, SL: 0.9718, Reward: -1.0
# Signal: Buy Long, TP: 1.0138, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.1136, SL: 0.9728, Reward: -1.0
# Signal: Buy Long, TP: 1.0139, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0135, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0113, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0129, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0131, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0109, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0133, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0132, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0116, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0112, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.1464, SL: 0.9714, Reward: -1.0
# Signal: Buy Long, TP: 1.0097, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1426, SL: 0.9708, Reward: -1.0
# Signal: Buy Long, TP: 1.1369, SL: 0.9708, Reward: -1.0
# Signal: Buy Long, TP: 1.0091, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.1182, SL: 0.9734, Reward: -1.0
# Signal: Buy Long, TP: 1.0978, SL: 0.9750, Reward: -1.0
# Signal: Buy Long, TP: 1.0138, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0139, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0147, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0140, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.1168, SL: 0.9725, Reward: -1.0
# Signal: Buy Long, TP: 1.0216, SL: 0.9873, Reward: 1.0
# Signal: Buy Long, TP: 1.0214, SL: 0.9872, Reward: 1.0
# Signal: Buy Long, TP: 1.1366, SL: 0.9683, Reward: -1.0
# Signal: Buy Long, TP: 1.0070, SL: 0.9895, Reward: 1.0
# Signal: Buy Long, TP: 1.1580, SL: 0.9709, Reward: -1.0
# Signal: Buy Long, TP: 1.1608, SL: 0.9705, Reward: -1.0
# Signal: Buy Long, TP: 1.0083, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.1302, SL: 0.9771, Reward: -1.0
# Signal: Buy Long, TP: 1.0191, SL: 0.9876, Reward: 1.0
# Signal: Buy Long, TP: 1.0201, SL: 0.9878, Reward: 1.0
# Signal: Buy Long, TP: 1.0186, SL: 0.9881, Reward: 1.0
# Signal: Buy Long, TP: 1.0184, SL: 0.9879, Reward: 1.0
# Signal: Buy Long, TP: 1.0175, SL: 0.9880, Reward: 1.0
# Signal: Buy Long, TP: 1.1214, SL: 0.9726, Reward: -1.0
# Signal: Buy Long, TP: 1.0147, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.1376, SL: 0.9703, Reward: -1.0
# Signal: Buy Long, TP: 1.0147, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0159, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0160, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.1237, SL: 0.9708, Reward: -1.0
# Signal: Buy Long, TP: 1.0156, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.0169, SL: 0.9879, Reward: 1.0
# Signal: Buy Long, TP: 1.0173, SL: 0.9881, Reward: 1.0
# Signal: Buy Long, TP: 1.1058, SL: 0.9732, Reward: -1.0
# Signal: Buy Long, TP: 1.0175, SL: 0.9881, Reward: 1.0
# Signal: Buy Long, TP: 1.0173, SL: 0.9882, Reward: 1.0
# Signal: Buy Long, TP: 1.0166, SL: 0.9881, Reward: 1.0
# Signal: Buy Long, TP: 1.0158, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.1132, SL: 0.9727, Reward: -1.0
# Signal: Buy Long, TP: 1.0137, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0144, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0145, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0153, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0142, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0131, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0130, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0124, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.1241, SL: 0.9732, Reward: -1.0
# Signal: Buy Long, TP: 1.0140, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0139, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.1015, SL: 0.9741, Reward: -1.0
# Signal: Buy Long, TP: 1.0143, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0140, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0136, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0133, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0146, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0130, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.1107, SL: 0.9713, Reward: -1.0
# Signal: Buy Long, TP: 1.0124, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.1517, SL: 0.9709, Reward: -1.0
# Signal: Buy Long, TP: 1.1486, SL: 0.9714, Reward: -1.0
# Signal: Buy Long, TP: 1.0116, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0154, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.0154, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.1149, SL: 0.9730, Reward: -1.0
# Signal: Buy Long, TP: 1.0159, SL: 0.9881, Reward: 1.0
# Signal: Buy Long, TP: 1.0160, SL: 0.9877, Reward: 1.0
# Signal: Buy Long, TP: 1.0151, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0143, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0139, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0131, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0137, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0128, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0133, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0123, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0124, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0130, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0140, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.1384, SL: 0.9727, Reward: -1.0
# Signal: Buy Long, TP: 1.0148, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0157, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0153, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.1743, SL: 0.9686, Reward: -1.0
# Signal: Buy Long, TP: 1.0148, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0149, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0131, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.1204, SL: 0.9661, Reward: -1.0
# Signal: Buy Long, TP: 1.0129, SL: 0.9876, Reward: 1.0
# Signal: Buy Long, TP: 1.1316, SL: 0.9723, Reward: -1.0
# Signal: Buy Long, TP: 1.1392, SL: 0.9652, Reward: -1.0
# Signal: Buy Long, TP: 1.1160, SL: 0.9748, Reward: -1.0
# Signal: Buy Long, TP: 1.1133, SL: 0.9699, Reward: -1.0
# Signal: Buy Long, TP: 1.0139, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0325, SL: 0.9838, Reward: 1.0
# Signal: Buy Long, TP: 1.0337, SL: 0.9815, Reward: 1.0
# Signal: Buy Long, TP: 1.1280, SL: 0.9685, Reward: -1.0
# Signal: Buy Long, TP: 1.0332, SL: 0.9837, Reward: 1.0
# Signal: Buy Long, TP: 1.0321, SL: 0.9842, Reward: 1.0
# Signal: Buy Long, TP: 1.1231, SL: 0.9710, Reward: -1.0
# Signal: Buy Long, TP: 1.1237, SL: 0.9705, Reward: -1.0
# Signal: Buy Long, TP: 1.0313, SL: 0.9863, Reward: 1.0
# Signal: Buy Long, TP: 1.0313, SL: 0.9845, Reward: 1.0
# Signal: Buy Long, TP: 1.0304, SL: 0.9850, Reward: 1.0
# Signal: Buy Long, TP: 1.0278, SL: 0.9852, Reward: 1.0
# Signal: Buy Long, TP: 1.1317, SL: 0.9729, Reward: -1.0
# Signal: Buy Long, TP: 1.1201, SL: 0.9737, Reward: -1.0
# Signal: Buy Long, TP: 1.0269, SL: 0.9857, Reward: 1.0
# Signal: Buy Long, TP: 1.0265, SL: 0.9858, Reward: 1.0
# Signal: Buy Long, TP: 1.0250, SL: 0.9862, Reward: 1.0
# Signal: Buy Long, TP: 1.0247, SL: 0.9859, Reward: 1.0
# Signal: Buy Long, TP: 1.1329, SL: 0.9741, Reward: -1.0
# Signal: Buy Long, TP: 1.0221, SL: 0.9870, Reward: 1.0
# Signal: Buy Long, TP: 1.0210, SL: 0.9872, Reward: 1.0
# Signal: Buy Long, TP: 1.1252, SL: 0.9702, Reward: -1.0
# Signal: Buy Long, TP: 1.0228, SL: 0.9871, Reward: 1.0
# Signal: Buy Long, TP: 1.0238, SL: 0.9868, Reward: 1.0
# Signal: Buy Long, TP: 1.1054, SL: 0.9742, Reward: -1.0
# Signal: Buy Long, TP: 1.0246, SL: 0.9865, Reward: 1.0
# Signal: Buy Long, TP: 1.0235, SL: 0.9865, Reward: 1.0
# Signal: Buy Long, TP: 1.0230, SL: 0.9870, Reward: 1.0
# Signal: Buy Long, TP: 1.0223, SL: 0.9868, Reward: 1.0
# Signal: Buy Long, TP: 1.0203, SL: 0.9871, Reward: 1.0
# Signal: Buy Long, TP: 1.0212, SL: 0.9873, Reward: 1.0
# Signal: Buy Long, TP: 1.0186, SL: 0.9879, Reward: 1.0
# Signal: Buy Long, TP: 1.0187, SL: 0.9878, Reward: 1.0
# Signal: Buy Long, TP: 1.1101, SL: 0.9745, Reward: -1.0
# Signal: Buy Long, TP: 1.1190, SL: 0.9728, Reward: -1.0
# Signal: Buy Long, TP: 1.1204, SL: 0.9725, Reward: -1.0
# Signal: Buy Long, TP: 1.1424, SL: 0.9716, Reward: -1.0
# Signal: Buy Long, TP: 1.1214, SL: 0.9719, Reward: -1.0
# Signal: Buy Long, TP: 1.0170, SL: 0.9882, Reward: 1.0
# Signal: Buy Long, TP: 1.0177, SL: 0.9879, Reward: 1.0
# Signal: Buy Long, TP: 1.0201, SL: 0.9873, Reward: 1.0
# Signal: Buy Long, TP: 1.1002, SL: 0.9723, Reward: -1.0
# Signal: Buy Long, TP: 1.1334, SL: 0.9702, Reward: -1.0
# Signal: Buy Long, TP: 1.0188, SL: 0.9877, Reward: 1.0
# Signal: Buy Long, TP: 1.1380, SL: 0.9695, Reward: -1.0
# Signal: Buy Long, TP: 1.0180, SL: 0.9878, Reward: 1.0
# Signal: Buy Long, TP: 1.0172, SL: 0.9880, Reward: 1.0
# Signal: Buy Long, TP: 1.0156, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.1192, SL: 0.9719, Reward: -1.0
# Signal: Buy Long, TP: 1.0155, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.1130, SL: 0.9723, Reward: -1.0
# Signal: Buy Long, TP: 1.0146, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0150, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0157, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.0156, SL: 0.9882, Reward: 1.0
# Signal: Buy Long, TP: 1.1027, SL: 0.9752, Reward: -1.0
# Signal: Buy Long, TP: 1.0146, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0165, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.1214, SL: 0.9728, Reward: -1.0
# Signal: Buy Long, TP: 1.0148, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0132, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0139, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0127, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0128, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0129, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0119, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0114, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1161, SL: 0.9726, Reward: -1.0
# Signal: Buy Long, TP: 1.0129, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0126, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0129, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.1073, SL: 0.9732, Reward: -1.0
# Signal: Buy Long, TP: 1.0300, SL: 0.9846, Reward: 1.0
# Signal: Buy Long, TP: 1.1109, SL: 0.9746, Reward: -1.0
# Signal: Buy Long, TP: 1.0292, SL: 0.9848, Reward: 1.0
# Signal: Buy Long, TP: 1.0275, SL: 0.9868, Reward: 1.0
# Signal: Buy Long, TP: 1.0290, SL: 0.9851, Reward: 1.0
# Signal: Buy Long, TP: 1.0280, SL: 0.9855, Reward: 1.0
# Signal: Buy Long, TP: 1.0264, SL: 0.9860, Reward: 1.0
# Signal: Buy Long, TP: 1.0253, SL: 0.9860, Reward: 1.0
# Signal: Buy Long, TP: 1.0252, SL: 0.9865, Reward: 1.0
# Signal: Buy Long, TP: 1.0237, SL: 0.9868, Reward: 1.0
# Signal: Buy Long, TP: 1.0214, SL: 0.9870, Reward: 1.0
# Signal: Buy Long, TP: 1.0190, SL: 0.9872, Reward: 1.0
# Signal: Buy Long, TP: 1.0230, SL: 0.9868, Reward: 1.0
# Signal: Buy Long, TP: 1.0228, SL: 0.9865, Reward: 1.0
# Signal: Buy Long, TP: 1.0145, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0128, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0124, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0133, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0133, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0135, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.1028, SL: 0.9681, Reward: -1.0
# Signal: Buy Long, TP: 1.1028, SL: 0.9645, Reward: -1.0
# Signal: Buy Long, TP: 1.0084, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.1273, SL: 0.9628, Reward: -1.0
# Signal: Buy Long, TP: 1.0076, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1308, SL: 0.9746, Reward: -1.0
# Signal: Buy Long, TP: 1.0069, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.1306, SL: 0.9742, Reward: -1.0
# Signal: Buy Long, TP: 1.0125, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0124, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0120, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0115, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0105, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0126, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.1006, SL: 0.9756, Reward: -1.0
# Signal: Buy Long, TP: 1.0990, SL: 0.9759, Reward: -1.0
# Signal: Buy Long, TP: 1.0106, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0102, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0137, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.1421, SL: 0.9725, Reward: -1.0
# Signal: Buy Long, TP: 1.1564, SL: 0.9686, Reward: -1.0
# Signal: Buy Long, TP: 1.1344, SL: 0.9694, Reward: -1.0
# Signal: Buy Long, TP: 1.1440, SL: 0.9705, Reward: -1.0
# Signal: Buy Long, TP: 1.0093, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0161, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.1356, SL: 0.9722, Reward: -1.0
# Signal: Buy Long, TP: 1.1010, SL: 0.9752, Reward: -1.0
# Signal: Buy Long, TP: 1.0158, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.1569, SL: 0.9709, Reward: -1.0
# Signal: Buy Long, TP: 1.0152, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0150, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.0133, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0133, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0111, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0089, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0096, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.1313, SL: 0.9733, Reward: -1.0
# Signal: Buy Long, TP: 1.0093, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.1264, SL: 0.9714, Reward: -1.0
# Signal: Buy Long, TP: 1.0132, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0122, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0123, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0118, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0100, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0097, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0087, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0096, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0102, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0096, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0103, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0104, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.1062, SL: 0.9733, Reward: -1.0
# Signal: Buy Long, TP: 1.0100, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1206, SL: 0.9744, Reward: -1.0
# Signal: Buy Long, TP: 1.0091, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0100, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1479, SL: 0.9716, Reward: -1.0
# Signal: Buy Long, TP: 1.0090, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0086, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.1176, SL: 0.9718, Reward: -1.0
# Signal: Buy Long, TP: 1.1456, SL: 0.9717, Reward: -1.0
# Signal: Buy Long, TP: 1.0075, SL: 0.9894, Reward: 1.0
# Signal: Buy Long, TP: 1.0076, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0075, SL: 0.9894, Reward: 1.0
# Signal: Buy Long, TP: 1.0072, SL: 0.9894, Reward: 1.0
# Signal: Buy Long, TP: 1.0088, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0093, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0091, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.1454, SL: 0.9722, Reward: -1.0
# Signal: Buy Long, TP: 1.0089, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0097, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0088, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0088, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1195, SL: 0.9718, Reward: -1.0
# Signal: Buy Long, TP: 1.0092, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0088, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0073, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0066, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0067, SL: 0.9894, Reward: 1.0
# Signal: Buy Long, TP: 1.0094, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0065, SL: 0.9894, Reward: 1.0
# Signal: Buy Long, TP: 1.1390, SL: 0.9706, Reward: -1.0
# Signal: Buy Long, TP: 1.0070, SL: 0.9894, Reward: 1.0
# Signal: Buy Long, TP: 1.1306, SL: 0.9712, Reward: -1.0
# Signal: Buy Long, TP: 1.1189, SL: 0.9740, Reward: -1.0
# Signal: Buy Long, TP: 1.1118, SL: 0.9730, Reward: -1.0
# Signal: Buy Long, TP: 1.0313, SL: 0.9841, Reward: 1.0
# Signal: Buy Long, TP: 1.0298, SL: 0.9847, Reward: 1.0
# Signal: Buy Long, TP: 1.0296, SL: 0.9848, Reward: 1.0
# Signal: Buy Long, TP: 1.0284, SL: 0.9851, Reward: 1.0
# Signal: Buy Long, TP: 1.1085, SL: 0.9727, Reward: -1.0
# Signal: Buy Long, TP: 1.0288, SL: 0.9852, Reward: 1.0
# Signal: Buy Long, TP: 1.1418, SL: 0.9710, Reward: -1.0
# Signal: Buy Long, TP: 1.1153, SL: 0.9749, Reward: -1.0
# Signal: Buy Long, TP: 1.1371, SL: 0.9737, Reward: -1.0
# Signal: Buy Long, TP: 1.0758, SL: 0.9721, Reward: -1.0
# Signal: Buy Long, TP: 1.1413, SL: 0.9712, Reward: -1.0
# Signal: Buy Long, TP: 1.0224, SL: 0.9871, Reward: 1.0
# Signal: Buy Long, TP: 1.1462, SL: 0.9691, Reward: -1.0
# Signal: Buy Long, TP: 1.1016, SL: 0.9709, Reward: -1.0
# Signal: Buy Long, TP: 1.1168, SL: 0.9732, Reward: -1.0
# Signal: Buy Long, TP: 1.1172, SL: 0.9713, Reward: -1.0
# Signal: Buy Long, TP: 1.1292, SL: 0.9725, Reward: -1.0
# Signal: Buy Long, TP: 1.0164, SL: 0.9880, Reward: 1.0
# Signal: Buy Long, TP: 1.1365, SL: 0.9709, Reward: -1.0
# Signal: Buy Long, TP: 1.1368, SL: 0.9716, Reward: -1.0
# Signal: Buy Long, TP: 1.1352, SL: 0.9664, Reward: -1.0
# Signal: Buy Long, TP: 1.1341, SL: 0.9710, Reward: -1.0
# Signal: Buy Long, TP: 1.0145, SL: 0.9872, Reward: 1.0
# Signal: Buy Long, TP: 1.1207, SL: 0.9677, Reward: -1.0
# Signal: Buy Long, TP: 1.1355, SL: 0.9723, Reward: -1.0
# Signal: Buy Long, TP: 1.1321, SL: 0.9664, Reward: -1.0
# Signal: Buy Long, TP: 1.0120, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.1321, SL: 0.9723, Reward: -1.0
# Signal: Buy Long, TP: 1.1229, SL: 0.9725, Reward: -1.0
# Signal: Buy Long, TP: 1.0281, SL: 0.9857, Reward: 1.0
# Signal: Buy Long, TP: 1.1251, SL: 0.9750, Reward: -1.0
# Signal: Buy Long, TP: 1.0262, SL: 0.9864, Reward: 1.0
# Signal: Buy Long, TP: 1.0256, SL: 0.9866, Reward: 1.0
# Signal: Buy Long, TP: 1.0252, SL: 0.9867, Reward: 1.0
# Signal: Buy Long, TP: 1.0258, SL: 0.9866, Reward: 1.0
# Signal: Buy Long, TP: 1.0235, SL: 0.9866, Reward: 1.0
# Signal: Buy Long, TP: 1.0514, SL: 0.9825, Reward: -1.0
# Signal: Buy Long, TP: 1.0228, SL: 0.9864, Reward: 1.0
# Signal: Buy Long, TP: 1.0219, SL: 0.9863, Reward: 1.0
# Signal: Buy Long, TP: 1.0237, SL: 0.9861, Reward: 1.0
# Signal: Buy Long, TP: 1.0247, SL: 0.9858, Reward: 1.0
# Signal: Buy Long, TP: 1.0241, SL: 0.9862, Reward: 1.0
# Signal: Buy Long, TP: 1.0225, SL: 0.9876, Reward: 1.0
# Signal: Buy Long, TP: 1.0225, SL: 0.9868, Reward: 1.0
# Signal: Buy Long, TP: 1.0209, SL: 0.9873, Reward: 1.0
# Signal: Buy Long, TP: 1.1052, SL: 0.9763, Reward: -1.0
# Signal: Buy Long, TP: 1.0366, SL: 0.9815, Reward: 1.0
# Signal: Buy Long, TP: 1.0343, SL: 0.9824, Reward: 1.0
# Signal: Buy Long, TP: 1.0320, SL: 0.9836, Reward: 1.0
# Signal: Buy Long, TP: 1.0321, SL: 0.9817, Reward: 1.0
# Signal: Buy Long, TP: 1.0323, SL: 0.9829, Reward: 1.0
# Signal: Buy Long, TP: 1.0305, SL: 0.9839, Reward: 1.0
# Signal: Buy Long, TP: 1.0303, SL: 0.9844, Reward: 1.0
# Signal: Buy Long, TP: 1.0279, SL: 0.9850, Reward: 1.0
# Signal: Buy Long, TP: 1.0252, SL: 0.9846, Reward: 1.0
# Signal: Buy Long, TP: 1.0247, SL: 0.9862, Reward: 1.0
# Signal: Buy Long, TP: 1.0231, SL: 0.9867, Reward: 1.0
# Signal: Buy Long, TP: 1.0245, SL: 0.9863, Reward: 1.0
# Signal: Buy Long, TP: 1.0241, SL: 0.9869, Reward: 1.0
# Signal: Buy Long, TP: 1.1109, SL: 0.9732, Reward: -1.0
# Signal: Buy Long, TP: 1.1147, SL: 0.9711, Reward: -1.0
# Signal: Buy Long, TP: 1.1134, SL: 0.9735, Reward: -1.0
# Signal: Buy Long, TP: 1.0280, SL: 0.9856, Reward: 1.0
# Signal: Buy Long, TP: 1.0269, SL: 0.9859, Reward: 1.0
# Signal: Buy Long, TP: 1.0263, SL: 0.9860, Reward: 1.0
# Signal: Buy Long, TP: 1.0253, SL: 0.9863, Reward: 1.0
# Signal: Buy Long, TP: 1.0243, SL: 0.9866, Reward: 1.0
# Signal: Buy Long, TP: 1.0223, SL: 0.9868, Reward: 1.0
# Signal: Buy Long, TP: 1.0239, SL: 0.9867, Reward: 1.0
# Signal: Buy Long, TP: 1.0242, SL: 0.9870, Reward: 1.0
# Signal: Buy Long, TP: 1.0238, SL: 0.9870, Reward: 1.0
# Signal: Buy Long, TP: 1.0229, SL: 0.9868, Reward: 1.0
# Signal: Buy Long, TP: 1.0759, SL: 0.9762, Reward: -1.0
# Signal: Buy Long, TP: 1.1196, SL: 0.9733, Reward: -1.0
# Signal: Buy Long, TP: 1.0216, SL: 0.9871, Reward: 1.0
# Signal: Buy Long, TP: 1.0213, SL: 0.9871, Reward: 1.0
# Signal: Buy Long, TP: 1.1178, SL: 0.9729, Reward: -1.0
# Signal: Buy Long, TP: 1.0197, SL: 0.9877, Reward: 1.0
# Signal: Buy Long, TP: 1.0261, SL: 0.9857, Reward: 1.0
# Signal: Buy Long, TP: 1.0256, SL: 0.9861, Reward: 1.0
# Signal: Buy Long, TP: 1.0314, SL: 0.9843, Reward: 1.0
# Signal: Buy Long, TP: 1.0306, SL: 0.9844, Reward: 1.0
# Signal: Buy Long, TP: 1.0285, SL: 0.9855, Reward: 1.0
# Signal: Buy Long, TP: 1.0266, SL: 0.9860, Reward: 1.0
# Signal: Buy Long, TP: 1.0251, SL: 0.9861, Reward: 1.0
# Signal: Buy Long, TP: 1.1247, SL: 0.9731, Reward: -1.0
# Signal: Buy Long, TP: 1.0235, SL: 0.9863, Reward: 1.0
# Signal: Buy Long, TP: 1.0236, SL: 0.9869, Reward: 1.0
# Signal: Buy Long, TP: 1.0239, SL: 0.9868, Reward: 1.0
# Signal: Buy Long, TP: 1.0197, SL: 0.9877, Reward: 1.0
# Signal: Buy Long, TP: 1.0207, SL: 0.9873, Reward: 1.0
# Signal: Buy Long, TP: 1.0201, SL: 0.9875, Reward: 1.0
# Signal: Buy Long, TP: 1.0206, SL: 0.9872, Reward: 1.0
# Signal: Buy Long, TP: 1.0193, SL: 0.9875, Reward: 1.0
# Signal: Buy Long, TP: 1.0133, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.1388, SL: 0.9724, Reward: -1.0
# Signal: Buy Long, TP: 1.0163, SL: 0.9880, Reward: 1.0
# Signal: Buy Long, TP: 1.0165, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.0161, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0162, SL: 0.9882, Reward: 1.0
# Signal: Buy Long, TP: 1.0157, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.0157, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0152, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0141, SL: 0.9882, Reward: 1.0
# Signal: Buy Long, TP: 1.0144, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0144, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0136, SL: 0.9882, Reward: 1.0
# Signal: Buy Long, TP: 1.0128, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0124, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.1490, SL: 0.9705, Reward: -1.0
# Signal: Buy Long, TP: 1.0109, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.1105, SL: 0.9735, Reward: -1.0
# Signal: Buy Long, TP: 1.1549, SL: 0.9756, Reward: -1.0
# Signal: Buy Long, TP: 1.0146, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0118, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0115, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0110, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1212, SL: 0.9716, Reward: -1.0
# Signal: Buy Long, TP: 1.0108, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1128, SL: 0.9722, Reward: -1.0
# Signal: Buy Long, TP: 1.0113, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0115, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.1226, SL: 0.9715, Reward: -1.0
# Signal: Buy Long, TP: 1.0151, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.1192, SL: 0.9718, Reward: -1.0
# Signal: Buy Long, TP: 1.1028, SL: 0.9748, Reward: -1.0
# Signal: Buy Long, TP: 1.0154, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.0156, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.0164, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0164, SL: 0.9880, Reward: 1.0
# Signal: Buy Long, TP: 1.0146, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0153, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0139, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0131, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0134, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0125, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0129, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0138, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.1517, SL: 0.9638, Reward: -1.0
# Signal: Buy Long, TP: 1.1562, SL: 0.9639, Reward: -1.0
# Signal: Buy Long, TP: 1.1242, SL: 0.9658, Reward: -1.0
# Signal: Buy Long, TP: 1.1472, SL: 0.9699, Reward: -1.0
# Signal: Buy Long, TP: 1.1377, SL: 0.9682, Reward: -1.0
# Signal: Buy Long, TP: 1.1258, SL: 0.9697, Reward: -1.0
# Signal: Buy Long, TP: 1.1593, SL: 0.9708, Reward: -1.0
# Signal: Buy Long, TP: 1.0057, SL: 0.9896, Reward: 1.0
# Signal: Buy Long, TP: 1.1296, SL: 0.9667, Reward: -1.0
# Signal: Buy Long, TP: 1.1282, SL: 0.9667, Reward: -1.0
# Signal: Buy Long, TP: 1.0090, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0082, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0081, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0086, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1182, SL: 0.9696, Reward: -1.0
# Signal: Buy Long, TP: 1.1177, SL: 0.9703, Reward: -1.0
# Signal: Buy Long, TP: 1.1421, SL: 0.9720, Reward: -1.0
# Signal: Buy Long, TP: 1.0091, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0096, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0096, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0099, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0095, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0092, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0097, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0102, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0117, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0102, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0107, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1420, SL: 0.9725, Reward: -1.0
# Signal: Buy Long, TP: 1.0103, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0114, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.1236, SL: 0.9713, Reward: -1.0
# Signal: Buy Long, TP: 1.0115, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0105, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0103, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0098, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0097, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.1810, SL: 0.9522, Reward: -1.0
# Signal: Buy Long, TP: 1.0159, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0153, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.0161, SL: 0.9882, Reward: 1.0
# Signal: Buy Long, TP: 1.0142, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.1400, SL: 0.9712, Reward: -1.0
# Signal: Buy Long, TP: 1.0119, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0119, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0117, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0118, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0115, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0112, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0146, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0149, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.0141, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0138, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0133, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.1117, SL: 0.9726, Reward: -1.0
# Signal: Buy Long, TP: 1.0129, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0127, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0126, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0117, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0118, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0113, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0130, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0148, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.1352, SL: 0.9718, Reward: -1.0
# Signal: Buy Long, TP: 1.1024, SL: 0.9740, Reward: -1.0
# Signal: Buy Long, TP: 1.0149, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.1016, SL: 0.9744, Reward: -1.0
# Signal: Buy Long, TP: 1.0135, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0134, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.1004, SL: 0.9750, Reward: -1.0
# Signal: Buy Long, TP: 1.0204, SL: 0.9874, Reward: 1.0
# Signal: Buy Long, TP: 1.0221, SL: 0.9871, Reward: 1.0
# Signal: Buy Long, TP: 1.0215, SL: 0.9873, Reward: 1.0
# Signal: Buy Long, TP: 1.1640, SL: 0.9693, Reward: -1.0
# Signal: Buy Long, TP: 1.0205, SL: 0.9874, Reward: 1.0
# Signal: Buy Long, TP: 1.1170, SL: 0.9714, Reward: -1.0
# Signal: Buy Long, TP: 1.0324, SL: 0.9841, Reward: 1.0
# Signal: Buy Long, TP: 1.0325, SL: 0.9841, Reward: 1.0
# Signal: Buy Long, TP: 1.0302, SL: 0.9839, Reward: 1.0
# Signal: Buy Long, TP: 1.0309, SL: 0.9845, Reward: 1.0
# Signal: Buy Long, TP: 1.1014, SL: 0.9716, Reward: -1.0
# Signal: Buy Long, TP: 1.1287, SL: 0.9680, Reward: -1.0
# Signal: Buy Long, TP: 1.0271, SL: 0.9852, Reward: 1.0
# Signal: Buy Long, TP: 1.0261, SL: 0.9858, Reward: 1.0
# Signal: Buy Long, TP: 1.0222, SL: 0.9873, Reward: 1.0
# Signal: Buy Long, TP: 1.0223, SL: 0.9867, Reward: 1.0
# Signal: Buy Long, TP: 1.0226, SL: 0.9868, Reward: 1.0
# Signal: Buy Long, TP: 1.0308, SL: 0.9841, Reward: 1.0
# Signal: Buy Long, TP: 1.1223, SL: 0.9728, Reward: -1.0
# Signal: Buy Long, TP: 1.0288, SL: 0.9850, Reward: 1.0
# Signal: Buy Long, TP: 1.0284, SL: 0.9854, Reward: 1.0
# Signal: Buy Long, TP: 1.1198, SL: 0.9735, Reward: -1.0
# Signal: Buy Long, TP: 1.0252, SL: 0.9861, Reward: 1.0
# Signal: Buy Long, TP: 1.0254, SL: 0.9865, Reward: 1.0
# Signal: Buy Long, TP: 1.0257, SL: 0.9862, Reward: 1.0
# Signal: Buy Long, TP: 1.0243, SL: 0.9865, Reward: 1.0
# Signal: Buy Long, TP: 1.0213, SL: 0.9873, Reward: 1.0
# Signal: Buy Long, TP: 1.0206, SL: 0.9864, Reward: 1.0
# Signal: Buy Long, TP: 1.0203, SL: 0.9873, Reward: 1.0
# Signal: Buy Long, TP: 1.0196, SL: 0.9874, Reward: 1.0
# Signal: Buy Long, TP: 1.0197, SL: 0.9875, Reward: 1.0
# Signal: Buy Long, TP: 1.0191, SL: 0.9878, Reward: 1.0
# Signal: Buy Long, TP: 1.0183, SL: 0.9877, Reward: 1.0
# Signal: Buy Long, TP: 1.1097, SL: 0.9742, Reward: -1.0
# Signal: Buy Long, TP: 1.0182, SL: 0.9878, Reward: 1.0
# Signal: Buy Long, TP: 1.1313, SL: 0.9725, Reward: -1.0
# Signal: Buy Long, TP: 1.1213, SL: 0.9731, Reward: -1.0
# Signal: Buy Long, TP: 1.0181, SL: 0.9880, Reward: 1.0
# Signal: Buy Long, TP: 1.1189, SL: 0.9728, Reward: -1.0
# Signal: Buy Long, TP: 1.0208, SL: 0.9869, Reward: 1.0
# Signal: Buy Long, TP: 1.1164, SL: 0.9744, Reward: -1.0
# Signal: Buy Long, TP: 1.0199, SL: 0.9873, Reward: 1.0
# Signal: Buy Long, TP: 1.0214, SL: 0.9871, Reward: 1.0
# Signal: Buy Long, TP: 1.0213, SL: 0.9872, Reward: 1.0
# Signal: Buy Long, TP: 1.0200, SL: 0.9878, Reward: 1.0
# Signal: Buy Long, TP: 1.0192, SL: 0.9877, Reward: 1.0
# Signal: Buy Long, TP: 1.0173, SL: 0.9876, Reward: 1.0
# Signal: Buy Long, TP: 1.0172, SL: 0.9881, Reward: 1.0
# Signal: Buy Long, TP: 1.0171, SL: 0.9874, Reward: 1.0
# Signal: Buy Long, TP: 1.0152, SL: 0.9878, Reward: 1.0
# Signal: Buy Long, TP: 1.0283, SL: 0.9842, Reward: -1.0
# Signal: Buy Long, TP: 1.0155, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.1511, SL: 0.9696, Reward: -1.0
# Signal: Buy Long, TP: 1.0129, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.1094, SL: 0.9709, Reward: -1.0
# Signal: Buy Long, TP: 1.1025, SL: 0.9670, Reward: -1.0
# Signal: Buy Long, TP: 1.1276, SL: 0.9696, Reward: -1.0
# Signal: Buy Long, TP: 1.1314, SL: 0.9730, Reward: -1.0
# Signal: Buy Long, TP: 1.1445, SL: 0.9695, Reward: -1.0
# Signal: Buy Long, TP: 1.1338, SL: 0.9714, Reward: -1.0
# Signal: Buy Long, TP: 1.0134, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.1446, SL: 0.9695, Reward: -1.0
# Signal: Buy Long, TP: 1.0130, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.1383, SL: 0.9705, Reward: -1.0
# Signal: Buy Long, TP: 1.0130, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0123, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0118, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1266, SL: 0.9705, Reward: -1.0
# Signal: Buy Long, TP: 1.1729, SL: 0.9687, Reward: -1.0
# Signal: Buy Long, TP: 1.0125, SL: 0.9882, Reward: 1.0
# Signal: Buy Long, TP: 1.1145, SL: 0.9735, Reward: -1.0
# Signal: Buy Long, TP: 1.0140, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.1388, SL: 0.9715, Reward: -1.0
# Signal: Buy Long, TP: 1.0125, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0121, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0109, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.1381, SL: 0.9718, Reward: -1.0
# Signal: Buy Long, TP: 1.0117, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0099, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0112, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1023, SL: 0.9731, Reward: -1.0
# Signal: Buy Long, TP: 1.1467, SL: 0.9701, Reward: -1.0
# Signal: Buy Long, TP: 1.1491, SL: 0.9731, Reward: -1.0
# Signal: Buy Long, TP: 1.1630, SL: 0.9668, Reward: -1.0
# Signal: Buy Long, TP: 1.1155, SL: 0.9727, Reward: -1.0
# Signal: Buy Long, TP: 1.1364, SL: 0.9728, Reward: -1.0
# Signal: Buy Long, TP: 1.1404, SL: 0.9692, Reward: -1.0
# Signal: Buy Long, TP: 1.1358, SL: 0.9725, Reward: -1.0
# Signal: Buy Long, TP: 1.1222, SL: 0.9698, Reward: -1.0
# Signal: Buy Long, TP: 1.0052, SL: 0.9896, Reward: 1.0
# Signal: Buy Long, TP: 1.1510, SL: 0.9697, Reward: -1.0
# Signal: Buy Long, TP: 1.0064, SL: 0.9894, Reward: 1.0
# Signal: Buy Long, TP: 1.0065, SL: 0.9894, Reward: 1.0
# Signal: Buy Long, TP: 1.0049, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.1293, SL: 0.9667, Reward: -1.0
# Signal: Buy Long, TP: 1.0079, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0099, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.1035, SL: 0.9732, Reward: -1.0
# Signal: Buy Long, TP: 1.1294, SL: 0.9740, Reward: -1.0
# Signal: Buy Long, TP: 1.1464, SL: 0.9732, Reward: -1.0
# Signal: Buy Long, TP: 1.0098, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0095, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.1392, SL: 0.9714, Reward: -1.0
# Signal: Buy Long, TP: 1.1439, SL: 0.9713, Reward: -1.0
# Signal: Buy Long, TP: 1.0086, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0098, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0102, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0097, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1222, SL: 0.9720, Reward: -1.0
# Signal: Buy Long, TP: 1.0121, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0111, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1132, SL: 0.9728, Reward: -1.0
# Signal: Buy Long, TP: 1.0125, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.1353, SL: 0.9734, Reward: -1.0
# Signal: Buy Long, TP: 1.1258, SL: 0.9713, Reward: -1.0
# Signal: Buy Long, TP: 1.0144, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0138, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0133, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0127, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0127, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0121, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.1273, SL: 0.9711, Reward: -1.0
# Signal: Buy Long, TP: 1.1217, SL: 0.9711, Reward: -1.0
# Signal: Buy Long, TP: 1.1417, SL: 0.9677, Reward: -1.0
# Signal: Buy Long, TP: 1.1074, SL: 0.9725, Reward: -1.0
# Signal: Buy Long, TP: 1.0139, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.1371, SL: 0.9682, Reward: -1.0
# Signal: Buy Long, TP: 1.1343, SL: 0.9682, Reward: -1.0
# Signal: Buy Long, TP: 1.0130, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0166, SL: 0.9882, Reward: 1.0
# Signal: Buy Long, TP: 1.0161, SL: 0.9882, Reward: 1.0
# Signal: Buy Long, TP: 1.0173, SL: 0.9879, Reward: 1.0
# Signal: Buy Long, TP: 1.0160, SL: 0.9882, Reward: 1.0
# Signal: Buy Long, TP: 1.0167, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.0155, SL: 0.9882, Reward: 1.0
# Signal: Buy Long, TP: 1.0146, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.1303, SL: 0.9725, Reward: -1.0
# Signal: Buy Long, TP: 1.1126, SL: 0.9711, Reward: -1.0
# Signal: Buy Long, TP: 1.0142, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.1188, SL: 0.9708, Reward: -1.0
# Signal: Buy Long, TP: 1.0139, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.1133, SL: 0.9727, Reward: -1.0
# Signal: Buy Long, TP: 1.1151, SL: 0.9723, Reward: -1.0
# Signal: Buy Long, TP: 1.1313, SL: 0.9687, Reward: -1.0
# Signal: Buy Long, TP: 1.1031, SL: 0.9736, Reward: -1.0
# Signal: Buy Long, TP: 1.0154, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0993, SL: 0.9746, Reward: -1.0
# Signal: Buy Long, TP: 1.0102, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0112, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0103, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0100, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.1316, SL: 0.9732, Reward: -1.0
# Signal: Buy Long, TP: 1.0098, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0112, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0111, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0123, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0131, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0117, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.1265, SL: 0.9713, Reward: -1.0
# Signal: Buy Long, TP: 1.0130, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0123, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.1269, SL: 0.9706, Reward: -1.0
# Signal: Buy Long, TP: 1.0125, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0118, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1159, SL: 0.9726, Reward: -1.0
# Signal: Buy Long, TP: 1.0108, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0082, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0076, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0073, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0084, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0108, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0089, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0093, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0090, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0090, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0092, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0094, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0083, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0097, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0105, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0108, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.1287, SL: 0.9730, Reward: -1.0
# Signal: Buy Long, TP: 1.1165, SL: 0.9721, Reward: -1.0
# Signal: Buy Long, TP: 1.0108, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0109, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.1150, SL: 0.9726, Reward: -1.0
# Signal: Buy Long, TP: 1.1135, SL: 0.9732, Reward: -1.0
# Signal: Buy Long, TP: 1.0095, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0103, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0093, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0770, SL: 0.9801, Reward: -1.0
# Signal: Buy Long, TP: 1.1567, SL: 0.9712, Reward: -1.0
# Signal: Buy Long, TP: 1.1397, SL: 0.9709, Reward: -1.0
# Signal: Buy Long, TP: 1.0085, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0080, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0080, SL: 0.9894, Reward: 1.0
# Signal: Buy Long, TP: 1.0081, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.1302, SL: 0.9713, Reward: -1.0
# Signal: Buy Long, TP: 1.0100, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0099, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0098, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0093, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0106, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.1339, SL: 0.9732, Reward: -1.0
# Signal: Buy Long, TP: 1.0119, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0115, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0116, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.1141, SL: 0.9699, Reward: -1.0
# Signal: Buy Long, TP: 1.1478, SL: 0.9691, Reward: -1.0
# Signal: Buy Long, TP: 1.0103, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0097, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0093, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0088, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0080, SL: 0.9894, Reward: 1.0
# Signal: Buy Long, TP: 1.1230, SL: 0.9711, Reward: -1.0
# Signal: Buy Long, TP: 1.1465, SL: 0.9669, Reward: -1.0
# Signal: Buy Long, TP: 1.1137, SL: 0.9718, Reward: -1.0
# Signal: Buy Long, TP: 1.0083, SL: 0.9894, Reward: 1.0
# Signal: Buy Long, TP: 1.1113, SL: 0.9720, Reward: -1.0
# Signal: Buy Long, TP: 1.1604, SL: 0.9707, Reward: -1.0
# Signal: Buy Long, TP: 1.0117, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0103, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0113, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1230, SL: 0.9720, Reward: -1.0
# Signal: Buy Long, TP: 1.0119, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.1514, SL: 0.9710, Reward: -1.0
# Signal: Buy Long, TP: 1.0103, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0104, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0098, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0096, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0094, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.1200, SL: 0.9717, Reward: -1.0
# Signal: Buy Long, TP: 1.0124, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0120, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.1083, SL: 0.9727, Reward: -1.0
# Signal: Buy Long, TP: 1.0129, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.1179, SL: 0.9662, Reward: -1.0
# Signal: Buy Long, TP: 1.1351, SL: 0.9696, Reward: -1.0
# Signal: Buy Long, TP: 1.0139, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0154, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.0132, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0134, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0127, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.1458, SL: 0.9704, Reward: -1.0
# Signal: Buy Long, TP: 1.1268, SL: 0.9727, Reward: -1.0
# Signal: Buy Long, TP: 1.0116, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.1321, SL: 0.9734, Reward: -1.0
# Signal: Buy Long, TP: 1.0137, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.1242, SL: 0.9737, Reward: -1.0
# Signal: Buy Long, TP: 1.0131, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.1222, SL: 0.9729, Reward: -1.0
# Signal: Buy Long, TP: 1.0133, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0137, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.1553, SL: 0.9682, Reward: -1.0
# Signal: Buy Long, TP: 1.0091, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.1160, SL: 0.9705, Reward: -1.0
# Signal: Buy Long, TP: 1.1330, SL: 0.9732, Reward: -1.0
# Signal: Buy Long, TP: 1.1625, SL: 0.9690, Reward: -1.0
# Signal: Buy Long, TP: 1.1519, SL: 0.9680, Reward: -1.0
# Signal: Buy Long, TP: 1.1042, SL: 0.9697, Reward: -1.0
# Signal: Buy Long, TP: 1.1336, SL: 0.9717, Reward: -1.0
# Signal: Buy Long, TP: 1.1413, SL: 0.9651, Reward: -1.0
# Signal: Buy Long, TP: 1.0794, SL: 0.9775, Reward: -1.0
# Signal: Buy Long, TP: 1.0090, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.1425, SL: 0.9715, Reward: -1.0
# Signal: Buy Long, TP: 1.1319, SL: 0.9716, Reward: -1.0
# Signal: Buy Long, TP: 1.0114, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0122, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0124, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0109, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0118, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0108, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0112, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0108, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0104, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0119, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.1318, SL: 0.9729, Reward: -1.0
# Signal: Buy Long, TP: 1.0123, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0121, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.1063, SL: 0.9732, Reward: -1.0
# Signal: Buy Long, TP: 1.0458, SL: 0.9841, Reward: -1.0
# Signal: Buy Long, TP: 1.0102, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0109, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1524, SL: 0.9718, Reward: -1.0
# Signal: Buy Long, TP: 1.0119, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0096, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0098, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.1261, SL: 0.9724, Reward: -1.0
# Signal: Buy Long, TP: 1.0093, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0101, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.1350, SL: 0.9614, Reward: -1.0
# Signal: Buy Long, TP: 1.1297, SL: 0.9750, Reward: -1.0
# Signal: Buy Long, TP: 1.0058, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0054, SL: 0.9894, Reward: 1.0
# Signal: Buy Long, TP: 1.1262, SL: 0.9675, Reward: -1.0
# Signal: Buy Long, TP: 1.1442, SL: 0.9696, Reward: -1.0
# Signal: Buy Long, TP: 1.1199, SL: 0.9771, Reward: -1.0
# Signal: Buy Long, TP: 1.1441, SL: 0.9695, Reward: -1.0
# Signal: Buy Long, TP: 1.1272, SL: 0.9708, Reward: -1.0
# Signal: Buy Long, TP: 1.0583, SL: 0.9819, Reward: -1.0
# Signal: Buy Long, TP: 1.1296, SL: 0.9757, Reward: -1.0
# Signal: Buy Long, TP: 1.0141, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0143, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0140, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0138, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.1235, SL: 0.9719, Reward: -1.0
# Signal: Buy Long, TP: 1.0131, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0135, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0138, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0129, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.1526, SL: 0.9695, Reward: -1.0
# Signal: Buy Long, TP: 1.0124, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.1152, SL: 0.9726, Reward: -1.0
# Signal: Buy Long, TP: 1.0143, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0959, SL: 0.9730, Reward: -1.0
# Signal: Buy Long, TP: 1.0146, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0151, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.0147, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.0138, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0970, SL: 0.9753, Reward: -1.0
# Signal: Buy Long, TP: 1.0133, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0131, SL: 0.9887, Reward: 1.0
# Signal: Buy Long, TP: 1.0144, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0151, SL: 0.9884, Reward: 1.0
# Signal: Buy Long, TP: 1.1060, SL: 0.9733, Reward: -1.0
# Signal: Buy Long, TP: 1.0190, SL: 0.9876, Reward: 1.0
# Signal: Buy Long, TP: 1.0201, SL: 0.9875, Reward: 1.0
# Signal: Buy Long, TP: 1.0191, SL: 0.9879, Reward: 1.0
# Signal: Buy Long, TP: 1.0181, SL: 0.9878, Reward: 1.0
# Signal: Buy Long, TP: 1.0200, SL: 0.9875, Reward: 1.0
# Signal: Buy Long, TP: 1.0201, SL: 0.9877, Reward: 1.0
# Signal: Buy Long, TP: 1.0204, SL: 0.9873, Reward: 1.0
# Signal: Buy Long, TP: 1.0196, SL: 0.9877, Reward: 1.0
# Signal: Buy Long, TP: 1.0196, SL: 0.9875, Reward: 1.0
# Signal: Buy Long, TP: 1.0201, SL: 0.9876, Reward: 1.0
# Signal: Buy Long, TP: 1.1308, SL: 0.9721, Reward: -1.0
# Signal: Buy Long, TP: 1.0176, SL: 0.9881, Reward: 1.0
# Signal: Buy Long, TP: 1.0172, SL: 0.9879, Reward: 1.0
# Signal: Buy Long, TP: 1.0163, SL: 0.9883, Reward: 1.0
# Signal: Buy Long, TP: 1.1216, SL: 0.9732, Reward: -1.0
# Signal: Buy Long, TP: 1.0151, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.0149, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.0153, SL: 0.9885, Reward: 1.0
# Signal: Buy Long, TP: 1.1116, SL: 0.9730, Reward: -1.0
# Signal: Buy Long, TP: 1.0147, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.1105, SL: 0.9732, Reward: -1.0
# Signal: Buy Long, TP: 1.1097, SL: 0.9733, Reward: -1.0
# Signal: Buy Long, TP: 1.0131, SL: 0.9888, Reward: 1.0
# Signal: Buy Long, TP: 1.0131, SL: 0.9886, Reward: 1.0
# Signal: Buy Long, TP: 1.1305, SL: 0.9705, Reward: -1.0
# Signal: Buy Long, TP: 1.0103, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0119, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.0115, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.1012, SL: 0.9742, Reward: -1.0
# Signal: Buy Long, TP: 1.1157, SL: 0.9758, Reward: -1.0
# Signal: Buy Long, TP: 1.0103, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1436, SL: 0.9739, Reward: -1.0
# Signal: Buy Long, TP: 1.0089, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0101, SL: 0.9889, Reward: 1.0
# Signal: Buy Long, TP: 1.0096, SL: 0.9890, Reward: 1.0
# Signal: Buy Long, TP: 1.1243, SL: 0.9719, Reward: -1.0
# Signal: Buy Long, TP: 1.1203, SL: 0.9718, Reward: -1.0
# Signal: Buy Long, TP: 1.1688, SL: 0.9681, Reward: -1.0
# Signal: Buy Long, TP: 1.1161, SL: 0.9720, Reward: -1.0
# Signal: Buy Long, TP: 1.0086, SL: 0.9891, Reward: 1.0
# Signal: Buy Long, TP: 1.0077, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.1077, SL: 0.9727, Reward: -1.0
# Signal: Buy Long, TP: 1.1483, SL: 0.9676, Reward: -1.0
# Signal: Buy Long, TP: 1.1505, SL: 0.9715, Reward: -1.0
# Signal: Buy Long, TP: 1.0090, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0088, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.1556, SL: 0.9688, Reward: -1.0
# Signal: Buy Long, TP: 1.0921, SL: 0.9701, Reward: -1.0
# Signal: Buy Long, TP: 1.0930, SL: 0.9697, Reward: -1.0
# Signal: Buy Long, TP: 1.1255, SL: 0.9717, Reward: -1.0
# Signal: Buy Long, TP: 1.1493, SL: 0.9641, Reward: -1.0
# Signal: Buy Long, TP: 1.1147, SL: 0.9630, Reward: -1.0
# Signal: Buy Long, TP: 1.0065, SL: 0.9895, Reward: 1.0
# Signal: Buy Long, TP: 1.1603, SL: 0.9705, Reward: -1.0
# Signal: Buy Long, TP: 1.1485, SL: 0.9697, Reward: -1.0
# Signal: Buy Long, TP: 1.0072, SL: 0.9894, Reward: 1.0
# Signal: Buy Long, TP: 1.1287, SL: 0.9675, Reward: -1.0
# Signal: Buy Long, TP: 1.0068, SL: 0.9895, Reward: 1.0
# Signal: Buy Long, TP: 1.0082, SL: 0.9893, Reward: 1.0
# Signal: Buy Long, TP: 1.0072, SL: 0.9894, Reward: 1.0
# Signal: Buy Long, TP: 1.0067, SL: 0.9894, Reward: 1.0
# Signal: Buy Long, TP: 1.0071, SL: 0.9892, Reward: 1.0
# Signal: Buy Long, TP: 1.0077, SL: 0.9892, Reward: 1.0
#
# 总奖励: 317.0
# 平均奖励: 0.3412
